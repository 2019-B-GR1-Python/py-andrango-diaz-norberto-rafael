# %%
import numpy as np
from scipy import ndimage
from scipy import misc
# Out:
# C:\Users\USRBET\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\USRBET\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\USRBET\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
mpache = misc.face()
mpache
# Out:
# array([[[121, 112, 131],
#         [138, 129, 148],
#         [153, 144, 165],
#         ...,
#         [119, 126,  74],
#         [131, 136,  82],
#         [139, 144,  90]],
#
#        [[ 89,  82, 100],
#         [110, 103, 121],
#         [130, 122, 143],
#         ...,
#         [118, 125,  71],
#         [134, 141,  87],
#         [146, 153,  99]],
#
#        [[ 73,  66,  84],
#         [ 94,  87, 105],
#         [115, 108, 126],
#         ...,
#         [117, 126,  71],
#         [133, 142,  87],
#         [144, 153,  98]],
#
#        ...,
#
#        [[ 87, 106,  76],
#         [ 94, 110,  81],
#         [107, 124,  92],
#         ...,
#         [120, 158,  97],
#         [119, 157,  96],
#         [119, 158,  95]],
#
#        [[ 85, 101,  72],
#         [ 95, 111,  82],
#         [112, 127,  96],
#         ...,
#         [121, 157,  96],
#         [120, 156,  94],
#         [120, 156,  94]],
#
#        [[ 85, 101,  74],
#         [ 97, 113,  84],
#         [111, 126,  97],
# ...

# %%
mpache.shape
# Out:
# (768, 1024, 3)

# %%
type(mpache)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(mpache)

# %%
plt.imshow(mpache[::-1])

# %%
mpache1, mpache2= np.split(mpache,2)
mpache_a, mpache_b= np.hsplit(mpache1,2)
mpache_c, mpache_d= np.hsplit(mpache2,2)
plt.imshow(mpache_a)

# %%
plt.imshow(mpache_b)

# %%
plt.imshow(mpache_c)

# %%
plt.imshow(mpache_d + 123)

# %%
#rmp=np.array([mpache_a, mpache_b, mpache_c, mpache_d])
rmp = misc.np.array([mpache_a, mpache_b, mpache_c, mpache_d])
plt.imshow(rmp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-fb19355ddb29> in <module>
#       1 #rmp=np.array([mpache_a, mpache_b, mpache_c, mpache_d])
#       2 rmp = misc.np.array([mpache_a, mpache_b, mpache_c, mpache_d])
# ----> 3 plt.imshow(rmp)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2675         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2676         resample=resample, url=url, **({"data": data} if data is not
# -> 2677         None else {}), **kwargs)
#    2678     sci(__ret)
#    2679     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
# ...

# %%
plt.imshow(mpache_d+1+1+1+244)

# %%
tr = ndimage.rotate(mpache_d,45)
plt.imshow(tr)

# %%
tr = ndimage.rotate(mpache_d,100)
plt.imshow(tr)

# %%
tr = ndimage.rotate(mpache,45)
plt.imshow(tr)

# %%
plt.imshow(misc.face(gray=True),cmap=plt.cm.gray )

# %%
plt.subplot(131)
plt.imshow(mpache_a)
plt.subplot(132)
plt.imshow(mpache_b)
plt.subplot(133)
plt.imshow(mpache_c)
plt.subplot(333)
plt.imshow(mpache_d)

plt.show()

# %% [markdown]
# # Titulo 1
# ## Titulo 2
